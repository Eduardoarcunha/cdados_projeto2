# %% [markdown]
# # Projeto 2  - Ciencia dos Dados
#
# ### Professor: Maria Kelly Venezuela
#
# ### Turma: 2A
#
# ### Alunos:
#
# Eduardo Araujo Rodrigues da Cunha
#
# Paulo Henrique Moreira Falcão
#
# Pedro Santos Rocha Von Dannecker

# %% [markdown]
# ___
#
# ## Intuito do projeto
#
# O projeto tem como objetivo, a partir de um base de dados, definir um target quantitativo, isto é, uma informação numérica, no caso, o banco de dado escolhido foi o de estatísticas de streamers da plataforma twitch durante um ano, e com estas informações, montar um modelo, que consiga prever o número de seguidores que um canal da plataforma ganhou, baseado em outras informações, como o número médio de viewers, tempo de stream, pico de viewers em um mesmo instante, entre outras.

# %% [markdown]
# <img src = "img_twitch.png"
#      width = 500
#      alt="Logo Twitch"
#      style="align:center;" />

# %% [markdown]
# ___
#
# ## Preparando os dados
# #### Importando bibliotecas básicas

# %%
import math
import os
import seaborn as sns
import numpy as np

import matplotlib.pyplot as plt
from numpy import arange
import pandas as pd
from scipy import stats

from IPython.display import display  # Para ter melhor print.

# %% [markdown]
# #### Import do Dataframe

# %%
dados = pd.read_csv('twitchdata-update.csv')

# %% [markdown]
# ___
#
# ## O Dataframe
#
# O Dataframe foi retirado do site [Kaggle](https://www.kaggle.com/aayushmishra1512/twitchdata), e tem dados de 1000 streamers da plataforma, as colunas do Dataframe são as seguintes:
# * **Channel:** Nome do canal do streamer, por exemplo, *Gaules*;
#
# * **Watch time(Minutes):** Tempo total de visualização no ano em minutos;
#
# * **Stream time(Minutes):** Tempo total em que a live ficou aberta no ano em minutos;
#
# * **Peak viewers:** O pico de usuarios assistindo a live ao mesmo tempo nesse ano;
#
# * **Average viewers:** Média de usuarios assistindo a live simultaneamente;
#
# * **Followers:** Número atual de seguidores;
#
# * **Followers gained:** Número de seguidores ganhos no último ano;
#
# * **Views gained:** Número de views ganhas no último ano;
#
# * **Partnered:** Se tem ou não uma parceria com a Twitch **(True ou False)**;
#
# * **Mature:** Se o conteúdo da live é recomendado ou não para maiores de 18 **(True ou False)**;
#
# * **Language:** Idioma da live;

# %%
dados.head(5)
# Out:
#     Channel  Watch time(Minutes)  Stream time(minutes)  Peak viewers  \
# 0     xQcOW           6196161750                215250        222720
# 1  summit1g           6091677300                211845        310998
# 2    Gaules           5644590915                515280        387315
# 3  ESL_CSGO           3970318140                517740        300575
# 4      Tfue           3671000070                123660        285644
#
#    Average viewers  Followers  Followers gained  Views gained  Partnered  \
# 0            27716    3246298           1734810      93036735       True
# 1            25610    5310163           1370184      89705964       True
# 2            10976    1767635           1023779     102611607       True
# 3             7714    3944850            703986     106546942       True
# 4            29602    8938903           2068424      78998587       True
#
#    Mature    Language
# 0   False     English
# 1   False     English
# 2    True  Portuguese
# 3   False     English
# 4   False     English

# %%
#Verificando se todos os tipos estão corretos:
dados.dtypes
# Out:
# Channel                 object
# Watch time(Minutes)      int64
# Stream time(minutes)     int64
# Peak viewers             int64
# Average viewers          int64
# Followers                int64
# Followers gained         int64
# Views gained             int64
# Partnered                 bool
# Mature                    bool
# Language                object
# dtype: object

# %%
#Consertando os tipos:
dados['Language'] = dados['Language'].astype('category')
dados.dtypes
# Out:
# Channel                   object
# Watch time(Minutes)        int64
# Stream time(minutes)       int64
# Peak viewers               int64
# Average viewers            int64
# Followers                  int64
# Followers gained           int64
# Views gained               int64
# Partnered                   bool
# Mature                      bool
# Language                category
# dtype: object

# %% [markdown]
# Assim, todas as variáveis já estão corretas.

# %%
dados['Initial followers'] = dados['Followers'] - dados['Followers gained']
dados.sort_values(['Initial followers'])
# Out:
#                Channel  Watch time(Minutes)  Stream time(minutes)  \
# 974          Sinner666            124812240                 24765
# 933      MadDecentLive            129993915                 42510
# 983        SlotRoom247            124078200                373800
# 669           SLAKUN10            179262330                  9555
# 145  木棉花官方頻道 (muse_tw)            625892895                446655
# ..                 ...                  ...                   ...
# 10        TimTheTatman           2834436990                108780
# 87             dakotaz            978947160                132615
# 35                Myth           1479214575                134760
# 4                 Tfue           3671000070                123660
# 96              shroud            888505170                 30240
#
#      Peak viewers  Average viewers  Followers  Followers gained  Views gained  \
# 974         27996             4530       7102              7101      21322548
# 933         36968             3069      95371             95352      44291541
# 983         20609              326      69183             69113       1338301
# 669         48358            18906    1874932           1874846       5835029
# 145         16702             1397     121053            120954      13670649
# ..            ...              ...        ...               ...           ...
# 10         142067            25664    5265659           1244341      50119786
# 87          43397             7112    4520305            489250      18504106
# 35         122552             9396    6726893           1421811      37384058
# 4          285644            29602    8938903           2068424      78998587
# 96         471281            29612    7744066            833587      30621257
#
#      Partnered  Mature Language  Initial followers
# 974      False   False  Russian                  1
# 933      False   False  English                 19
# 983      False    True   German                 70
# 669       True   False  Spanish                 86
# 145       True    True  Chinese                 99
# ..         ...     ...      ...                ...
# 10        True    True  English            4021318
# 87        True   False  English            4031055
# 35        True   False  English            5305082
# 4         True   False  English            6870479
# 96        True   False  English            6910479
#
# [1000 rows x 12 columns]

# %%
plt.hist(dados['Followers gained'], bins=50, density = True);

# %%
stats.probplot(dados['Followers gained'], dist=stats.expon, plot=plt);

# %%
df_quantitativo = dados.drop(['Channel','Partnered', 'Mature', 'Language'] , 1)

# %%
sns.set(style="ticks")
sns.pairplot(df_quantitativo, y_vars=['Followers gained'], x_vars=['Watch time(Minutes)', 'Stream time(minutes)', 'Peak viewers', 'Average viewers','Followers','Views gained', 'Initial followers']);

# %%
corrMatrix = df_quantitativo.corr()
corrMatrix = pd.DataFrame(corrMatrix['Followers gained'])
corrMatrix
# Out:
#                       Followers gained
# Watch time(Minutes)           0.514648
# Stream time(minutes)         -0.158165
# Peak viewers                  0.470415
# Average viewers               0.420097
# Followers                     0.715618
# Followers gained              1.000000
# Views gained                  0.244297
# Initial followers             0.386886

# %%
df_log = np.log(df_quantitativo);
# Out:
# <ipython-input-61-114f94f7ce42>:1: RuntimeWarning: invalid value encountered in log
#   df_log = np.log(df_quantitativo);

# %%
sns.set(style="ticks")
sns.pairplot(df_log, y_vars=['Followers gained'], x_vars=['Watch time(Minutes)', 'Stream time(minutes)', 'Peak viewers', 'Average viewers','Followers','Views gained', 'Initial followers']);

# %%
corrMatrix = df_log.corr()
corrMatrix = pd.DataFrame(corrMatrix['Followers gained'])
corrMatrix
# Out:
#                       Followers gained
# Watch time(Minutes)           0.456449
# Stream time(minutes)         -0.286205
# Peak viewers                  0.582791
# Average viewers               0.570031
# Followers                     0.682787
# Followers gained              1.000000
# Views gained                  0.389938
# Initial followers             0.203256

# %%
df_log.head()
# Out:
#    Watch time(Minutes)  Stream time(minutes)  Peak viewers  Average viewers  \
# 0            22.547196             12.279555     12.313671        10.229765
# 1            22.530189             12.263610     12.647542        10.150738
# 2            22.453964             13.152466     12.866994         9.303466
# 3            22.102112             13.157228     12.613453         8.950792
# 4            22.023730             11.725291     12.562502        10.295597
#
#    Followers  Followers gained  Views gained  Initial followers
# 0  14.993026         14.366408     18.348505          14.228605
# 1  15.485133         14.130456     18.312048          15.186686
# 2  14.385153         13.839011     18.446462          13.519603
# 3  15.187921         13.464514     18.484096          14.991351
# 4  16.005923         14.542298     18.184941          15.742744
